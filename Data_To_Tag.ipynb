# %%
import xlrd
loc = ("C:\Users\NARESH\Desktop\pramod\Temple\namelist.xlsx")
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 
sheet.cell_value(0,0)  
for i in range(sheet.nrows): 
    print(sheet.cell_value(i, 0))
# Out:
#   File "<ipython-input-6-0386905011de>", line 5
#     sheet.cell_value(0,0)
#                           ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd
import random
data=pd.read_excel(r"C:\Users\NARESH\Desktop\pramod\Temple\namelist.xlsx")
df=pd.DataFrame(data,columns=['पूर्ण नाव','देणगी रक्कम'])
count=0
table_class=["table-primary","table-secondary","table-success","table-info","table-warning","table-danger","table-active","table-light","table-dark"]
for i in df.index:
    count+=1
    print("<tr class=\"",random.choice(table_class),"\"><td>",count,"</td><td>",df['पूर्ण नाव'][i],"</td><td>",df['देणगी रक्कम'][i],"</td></tr>")
# Out:
# <tr class=" table-active "><td> 1 </td><td> दीपक रामचंद्र कदम </td><td> 5001 </td></tr>
# <tr class=" table-primary "><td> 2 </td><td> मंगेश राजेंद्र नलगे  </td><td> 2001 </td></tr>
# <tr class=" table-primary "><td> 3 </td><td> निवृत्ती अंबर खेडकर </td><td> 1111 </td></tr>
# <tr class=" table-active "><td> 4 </td><td> कुलदीप गुलाबराव पवार </td><td> 1001 </td></tr>
# <tr class=" table-success "><td> 5 </td><td> प्रदीप शिवाजी जाधव </td><td> 1111 </td></tr>
# <tr class=" table-active "><td> 6 </td><td> सचिन बाळासो काकडे </td><td> 1001 </td></tr>
# <tr class=" table-success "><td> 7 </td><td> सागर संजय पाटोळे </td><td> 1001 </td></tr>
# <tr class=" table-danger "><td> 8 </td><td> दीपक गणपत गुंड  </td><td> 1001 </td></tr>
# <tr class=" table-success "><td> 9 </td><td> शरद शिवाजी साळवे </td><td> 1001 </td></tr>
# <tr class=" table-primary "><td> 10 </td><td> मिलिंद मुकुंद पांडव </td><td> 5001 </td></tr>
# ...
